# %% [markdown]
# <div style="border:solid green 3px; padding: 20px">
# <b>🥇 Екатерина, спасибо за доработки, проект принят, молодец!</b>
#
# Ты провела очень хорошую работу над ошибками! Уверен, ты обязательно достигнешь своей цели! Успехов в дальнейшем обучении! 🙂

# %% [markdown]
# Екатерина, привет! Меня зовут Ефимов Денис и сегодня я буду делать ревью твоего проекта!\
# В Практикуме принято общаться на "ты", однако если это неудобно - дай знать, и можем перейти на более официальное общение.
#
# Ниже ты найдешь мои комментарии - пожалуйста, не перемещай, не изменяй и не удаляй их. Я буду использовать цветовую разметку:
#
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Если все сделано хорошо. </div>
#
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b> Некритичное замечание; если таких замечаний меньше трех — проект может быть принят без их отработки.</div>
#
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b> Грубая ошибка, необходимо исправить, иначе проект не будет принят.
# </div>
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
# Например так:
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Hello World! ✔
# </div>
#
# Или можешь использовать эту галочку ✔ в моих комментариях, если писать особо нечего.
#
# <div class="alert alert-block alert-warning">
# <b>Общее впечатление:</b>
#
# - Ты проделала огромную работу :)
# - У меня есть несколько замечаний, исправив которые ты сделаешь проект лучше.
# - Пробегись по моим комментариям, исправь недочёты и всё будет отлично :)
#
# </div>

# %% [markdown]
# # Выявление закономерностей, определяющих успешность игры

# %% [markdown]
# **Представим себя в качесте сотрудников интернет-магазина «Стримчик», который продаёт по всему миру компьютерные игры. Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation). Нам нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.<br>
# Перед нами данные до 2016 года. Представим, что сейчас декабрь 2016 г., и мы планируем кампанию на 2017-й. Нужно отработать принцип работы с данными. Неважно, прогнозируете ли мы продажи на 2017 год по данным 2016-го или же 2027-й — по данным 2026 года.<br>
# В наборе данных попадается аббревиатура ESRB (Entertainment Software Rating Board) — это ассоциация, определяющая возрастной рейтинг компьютерных игр. ESRB оценивает игровой контент и присваивает ему подходящую возрастную категорию, например, «Для взрослых», «Для детей младшего возраста» или «Для подростков».**

# %% [markdown]
# **Нам предоставлен csv-файл 'games' с данными о видеоиграх.**

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Молодец, что написала введение!  </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# Можно добавить описание имеющихся данных и примерный план действий.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Добавила описание данных и план работы
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# **Описание данных:<br>
# Name — название игры<br>
# Platform — платформа<br>
# Year_of_Release — год выпуска<br>
# Genre — жанр игры<br>
# NA_sales — продажи в Северной Америке (миллионы проданных копий)<br>
# EU_sales — продажи в Европе (миллионы проданных копий)<br>
# JP_sales — продажи в Японии (миллионы проданных копий)<br>
# Other_sales — продажи в других странах (миллионы проданных копий)<br>
# Critic_Score — оценка критиков (максимум 100)<br>
# User_Score — оценка пользователей (максимум 10)<br>
# Rating — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.<br>
# Данные за 2016 год могут быть неполными.**<br>

# %% [markdown]
# **План работы:<br>
# 1). Проведем предобработку данных: проверим их на наличие пропусков, аномалий и дубликатов. При необходимости избавимся от них.<br>
# 2). Проведем исследовательский анализ данных с целью актуализиции периода для построения прогноза продаж игр на 2017 год, а также выявления популярных платформ и жанров игр, наиболее потенциально прибыльных игр, а также игр, пользующихся признанием пользователей и критиков.<br>
# 3). Составим портрет пользователя каждого региона (исследуем популярные платформы, жанры и возрастные рейтинги по регионам).<br>
# 4). Проверим гипотезы:<br>
# -- Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;<br>
# -- Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.<br>
# 5). Напишем общий вывод с результатами проведенного нами исследования.**

# %% [markdown]
# ## Загрузка данных

# %%
# импортируем необходимые библиотеки
import pandas as pd
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as st

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Правильно, что импортируешь все библиотеки в отдельной ячейке!  </div>

# %%
# загрузим файл с данными
df = pd.read_csv('/datasets/games.csv')
df.head(10)
# Out:
#                         Name Platform  Year_of_Release         Genre  \
# 0                 Wii Sports      Wii           2006.0        Sports
# 1          Super Mario Bros.      NES           1985.0      Platform
# 2             Mario Kart Wii      Wii           2008.0        Racing
# 3          Wii Sports Resort      Wii           2009.0        Sports
# 4   Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                     Tetris       GB           1989.0        Puzzle
# 6      New Super Mario Bros.       DS           2006.0      Platform
# 7                   Wii Play      Wii           2006.0          Misc
# 8  New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9                  Duck Hunt      NES           1984.0       Shooter
#
#    NA_sales  EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     41.36     28.96      3.77         8.45          76.0          8      E
# ...

# %%
#выведем основную информацию по датасету
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# **Перед нами датасет из 11 колонок с 16715 строками. В некоторых строках встречаются пропущенные значения. Названия столбцов указаны с заглавной буквы, что не соответствует хорошему стилю. Также типы данных с столбцах 'Year_of_Release' и 'User_Score' не соответствуют их содержимому.**

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# Также стоит отметить корректность наименования столбцов и соответствие типов данных.</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Поправила)
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# ## Предобработка данных

# %%
#приведем названия колонок к нижнему регистру
df.columns = df.columns.str.lower()
df.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score user_score rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %%
#заменим пропущенные значения в столбце 'year_of_release' на 0 и изменим тип данных на целые числа
df['year_of_release'] = df['year_of_release'].fillna(0).astype('int')

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# Пропусков тут немного и их можно удалить, так как эти строки в любом случае не попадут в актуальный период.</div>

# %%
#приведем тип данных столбца 'user_score' к вещественным числам
df['user_score'] = pd.to_numeric(df['user_score'], errors='coerce')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16715 non-null  int64
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       7590 non-null   float64
#  10  rating           9949 non-null   object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# **Итак, мы заменили отсутствующие годы в столбце 'year_of_release' на 0, так как значения 'Nan' не позволяли нам изменить тип данных. Что же касается других столбцов - в некоторых из них ('critic_score', 'user_score', 'rating') так же встречаются пропущенные значения, но менять их представляется нецелесообразным. Это обычное дело в датафреймах - редко встречаются датафреймы совсем без пропусков, потому что как правило сложно собрать полностью исчерпывающую информацию. Будем работать с тем, что имеем.**

# %% [markdown]
# **Также при изменении типа данных столбца 'user_score' нам встретилось значение 'tbd'. Оно часто используется для обозначения "to be determined" или "to be decided" и не представляет собой конкретное численное значение. Поэтому прежде чем преобразовывать колонку 'user_score' в тип float, нам понадобилось обработать значения 'tbd' и заменить 'tbd' на значение по умолчанию (NaN).**

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Верное решение.</div>

# %% [markdown]
# **Взглянем на категориальные столбцы на предмет наличия неявных дубликатов или аномалий.**

# %%
df['platform'].unique()
# Out:
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        'PS4', '3DS', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne',
#        'WiiU', 'GC', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)

# %%
df['genre'].unique()
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy', nan], dtype=object)

# %%
df['rating'].unique()
# Out:
# array(['E', nan, 'M', 'T', 'E10+', 'K-A', 'AO', 'EC', 'RP'], dtype=object)

# %%
df['year_of_release'].unique()
# Out:
# array([2006, 1985, 2008, 2009, 1996, 1989, 1984, 2005, 1999, 2007, 2010,
#        2013, 2004, 1990, 1988, 2002, 2001, 2011, 1998, 2015, 2012, 2014,
#        1992, 1997, 1993, 1994, 1982, 2016, 2003, 1986, 2000,    0, 1995,
#        1991, 1981, 1987, 1980, 1983])

# %% [markdown]
# **Мы можем установить, что в нашем распоряжении информация по выпуску видеоигр с 1980 по 2016 годы.**

# %% [markdown]
# **С категориалиными столбцами все нормально. Посмотрим, нет ли анамалий в столбцах с продажами и оценками критиков.**

# %%
df['na_sales'].describe()
# Out:
# count    16715.000000
# mean         0.263377
# std          0.813604
# min          0.000000
# 25%          0.000000
# 50%          0.080000
# 75%          0.240000
# max         41.360000
# Name: na_sales, dtype: float64

# %%
df['eu_sales'].describe()
# Out:
# count    16715.000000
# mean         0.145060
# std          0.503339
# min          0.000000
# 25%          0.000000
# 50%          0.020000
# 75%          0.110000
# max         28.960000
# Name: eu_sales, dtype: float64

# %%
df['jp_sales'].describe()
# Out:
# count    16715.000000
# mean         0.077617
# std          0.308853
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.040000
# max         10.220000
# Name: jp_sales, dtype: float64

# %%
df['other_sales'].describe()
# Out:
# count    16715.000000
# mean         0.047342
# std          0.186731
# min          0.000000
# 25%          0.000000
# 50%          0.010000
# 75%          0.030000
# max         10.570000
# Name: other_sales, dtype: float64

# %%
df['critic_score'].describe()
# Out:
# count    8137.000000
# mean       68.967679
# std        13.938165
# min        13.000000
# 25%        60.000000
# 50%        71.000000
# 75%        79.000000
# max        98.000000
# Name: critic_score, dtype: float64

# %% [markdown]
# **С изученными столбцами так же все в порядке. Нет отрицательных значений и оценки критиков распределены с 13 до 98.**

# %% [markdown]
# **В столбце 'name' могут встречаться одинаковые названия игр, так как обычно одна и та же игра с одним и тем же названием выходит на разных платформах. Поэтому проверим, нет ли дубликатов сразу по всем строкам в датафрейме.**

# %%
duplicates  = df[df.duplicated(keep=False)]
duplicates
# Out:
# Empty DataFrame
# Columns: [name, platform, year_of_release, genre, na_sales, eu_sales, jp_sales, other_sales, critic_score, user_score, rating]
# Index: []

# %% [markdown]
# **Полных дубликатов не обнаружено.**

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# Также нужно обязательно сделать проверку на наличие неявных дубликатов (совпадающие по названию, платформе и году релиза одновременно).
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Сделала)
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %%
#также сделаем проверку на наличие дубликатов по названию, платформе и году релиза
implicit_dupl = df[df.duplicated(subset=['name', 'platform', 'year_of_release'], keep=False)]
implicit_dupl
# Out:
#                 name platform  year_of_release   genre  na_sales  eu_sales  \
# 604    Madden NFL 13      PS3             2012  Sports      2.11      0.22
# 659              NaN      GEN             1993     NaN      1.78      0.53
# 14244            NaN      GEN             1993     NaN      0.00      0.00
# 16230  Madden NFL 13      PS3             2012  Sports      0.00      0.01
#
#        jp_sales  other_sales  critic_score  user_score rating
# 604        0.00         0.23          83.0         5.5      E
# 659        0.00         0.08           NaN         NaN    NaN
# 14244      0.03         0.00           NaN         NaN    NaN
# 16230      0.00         0.00          83.0         5.5      E

# %% [markdown]
# **Так как найденных дубликатов немного, удалим их.**

# %%
df.drop(index=implicit_dupl.index, inplace=True)

# %% [markdown]
# **Посчитаем суммарные продажи во всех регионах и запишем их в отдельный столбец:**

# %%
df['total_sales'] = df['na_sales'] + df['eu_sales'] + df['jp_sales'] + df['other_sales']
df.head(10)
# Out:
#                         name platform  year_of_release         genre  \
# 0                 Wii Sports      Wii             2006        Sports
# 1          Super Mario Bros.      NES             1985      Platform
# 2             Mario Kart Wii      Wii             2008        Racing
# 3          Wii Sports Resort      Wii             2009        Sports
# 4   Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# 5                     Tetris       GB             1989        Puzzle
# 6      New Super Mario Bros.       DS             2006      Platform
# 7                   Wii Play      Wii             2006          Misc
# 8  New Super Mario Bros. Wii      Wii             2009      Platform
# 9                  Duck Hunt      NES             1984       Shooter
#
#    na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 0     41.36     28.96      3.77         8.45          76.0         8.0      E
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b>
#
# Еще тут можно использовать метод `DataFrame.sum` с аргументом `axis=1`</div>
#
# ```python
#
#         df['total_sum'] = df[['value_1', 'value_2', 'value_3', 'value_4']].sum(axis=1)
#
# ```

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# После этапа предобработки также нужно сделать краткий резюмирующий вывод о проделанной работе.</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Написала
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# **Мы провели этап предобработки данных: привели названия столбцов к нижнему регистру, изменили типы столбцов, проверили данные на наличие пропусков, аномалий и дубликатов и удалили их, добавили дополнительный столбец, необходимый нам для анализа.**

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# **Посмотрим, сколько игр выпускалось в разные годы:**

# %%
filtered_df = df[df['year_of_release'] != 0]
games_per_year = filtered_df['year_of_release'].value_counts(ascending=False)
# Преобразуем Series в DataFrame для корректной работы с Plotly Express
games_per_year_df = games_per_year.reset_index()
games_per_year_df.columns = ['Год выпуска', 'Количество игр']

# Визуализируем данные
fig = px.bar(games_per_year_df, x='Год выпуска', y='Количество игр', 
             title='Количество выпущенных игр по годам',
             labels={'Год выпуска': 'Год выпуска', 'Количество игр': 'Количество игр'},
             text='Количество игр')  # Используем 'Количество игр' в качестве текстовой информации
fig.show()
# Out:
# <div>                            <div id="f65f3d48-2262-4ec9-bab3-5d2ab1aed800" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f65f3d48-2262-4ec9-bab3-5d2ab1aed800")) {                    Plotly.newPlot(                        "f65f3d48-2262-4ec9-bab3-5d2ab1aed800",                        [{"alignmentgroup":"True","hovertemplate":"\u0413\u043e\u0434 \u0432\u044b\u043f\u0443\u0441\u043a\u0430=%{x}<br>\u041a\u043e\u043b\u0438\u0447\u0435\u0441\u0442\u0432\u043e \u0438\u0433\u0440=%{text}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[1427.0,1426.0,1255.0,1197.0,1136.0,1006.0,939.0,829.0,775.0,762.0,651.0,606.0,581.0,544.0,502.0,482.0,379.0,35
# ...

# %% [markdown]
# **Итак, мы видим, что до 1994 года выпускалось мало игр - эта индустрия еще только развивалась. Потом количество выпускаемых ежегодно игр стало резко расти. Пик мы наблюдаем в 2008 и 2009 годах (1427 и 1426 игр за год). Затем на графике виден спад в количестве выпускаемых ежегодно игр. Думаю это может быть обусловлено тем, что потребители стали более требовательными и искушенными, и разработка более современных игр требует больше времени на разработку, выявление и устранение багов, проработку сюжета, геймплея и т.п.**

# %% [markdown]
# **Посмотрим, как менялись продажи по платформам:**

# %%
sales_by_platform = df.groupby('platform')['total_sales'].sum().round().sort_values(ascending=False).reset_index()
# Визуализируем данные
fig = px.bar(sales_by_platform, x='platform', y='total_sales',
             title='Сумма продаж по платформам',
             labels={'platform': 'Платформа', 'total_sales': 'Сумма продаж'},
             text='total_sales')

fig.show()
# Out:
# <div>                            <div id="12728231-c4c3-46b0-a317-5acd185e6d48" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("12728231-c4c3-46b0-a317-5acd185e6d48")) {                    Plotly.newPlot(                        "12728231-c4c3-46b0-a317-5acd185e6d48",                        [{"alignmentgroup":"True","hovertemplate":"\u041f\u043b\u0430\u0442\u0444\u043e\u0440\u043c\u0430=%{x}<br>\u0421\u0443\u043c\u043c\u0430 \u043f\u0440\u043e\u0434\u0430\u0436=%{text}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[1256.0,971.0,937.0,908.0,806.0,731.0,318.0,314.0,294.0,260.0,259.0,258.0,255.0,251.0,219.0,200.0,199.0,159.0,97.0,82.0,54.0,34.0,
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Молодец ,что подписываешь графики и оси! </div>

# %% [markdown]
# **По полученной столбчатой диаграмме можно сделать однозначный вывод, что самыми популярными платформами за исследуемый период являлись PS2, X360, PS3, Wii, DS и PS. Интересное наблюдение - персональные компьютеры не вошли в топ, хотя, безусловно, они и имеют большее распространение.**

# %% [markdown]
# **Выберем платформы с наибольшими суммарными продажами и построим распределение по годам:**

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# Нужно всегда стараться писать более универсальный код, без ручного внесения данных. Если данные дополнятся или изменятся, то список платформ нам придется переписывать, при этом можно допустить ошибки. Лучше сразу формировать список платформ из полученной группировки по продажам и его потом использовать при фильтрации. Ниже написал пример. </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %%
# код ревьюера
df.groupby('platform').agg({'total_sales': 'sum'}).sort_values(by='total_sales', ascending=False).head(6).index.to_list()
# Out:
# ['PS2', 'X360', 'PS3', 'Wii', 'DS', 'PS']

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Исправила код)
# </div>

# %%
# Создаем список платформ
top_platforms = df.groupby('platform').agg({'total_sales': 'sum'}).sort_values(by='total_sales', ascending=False).head(6).index.to_list()
# Фильтруем DataFrame по топ-платформам и году выпуска
filtered_df2 = df[(df['platform'].isin(top_platforms)) & (df['year_of_release'] > 1993)]
# Распределение платформ по годам
platforms_per_year = filtered_df2.groupby(['year_of_release', 'platform']).size().reset_index(name='Количество игр')

# Визуализируем данные
fig = px.bar(platforms_per_year, x='year_of_release', y='Количество игр', color='platform',
             title='Распределение платформ по годам',
             labels={'year_of_release': 'Год выпуска игры', 'Количество игр': 'Количество игр', 'platform': 'Платформа'},
             color_discrete_sequence=px.colors.qualitative.Set1,
             text='Количество игр')  # Используем 'Количество игр' в качестве текстовой информации
fig.show()
# Out:
# <div>                            <div id="5e4e152d-2315-49ad-8f17-6b2407786f83" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5e4e152d-2315-49ad-8f17-6b2407786f83")) {                    Plotly.newPlot(                        "5e4e152d-2315-49ad-8f17-6b2407786f83",                        [{"alignmentgroup":"True","hovertemplate":"\u041f\u043b\u0430\u0442\u0444\u043e\u0440\u043c\u0430=PS<br>\u0413\u043e\u0434 \u0432\u044b\u043f\u0443\u0441\u043a\u0430 \u0438\u0433\u0440\u044b=%{x}<br>\u041a\u043e\u043b\u0438\u0447\u0435\u0441\u0442\u0432\u043e \u0438\u0433\u0440=%{text}<extra></extra>","legendgroup":"PS","marker":{"color":"rgb(228,26,28)","pattern":{"shape":""}},"name":"PS","offsetgroup":"PS","orientation":"v","showlegend":true,"text":[17.0,99.0,16
# ...

# %% [markdown]
# **По полученной диаграмме выходит, что c 1994 по 2001 много игр выходило на платформу PS, а с 2000 по 2008 - на платформу PS2.<br>
# С 2005 по 2011 DS занимала превосходные лидирующие позиции.<br>
# Популярность PS3 и X360 с 2006 по 2016 годы можно сказать являлась тождественной и абсолютно сопоставимой (как известно, это действительно конкурирующие игровые приставки-аналоги от Sony и Microsoft, относящиеся к одному поколению). Как мы видим, сначала немного выигрывал X360, а потом PS3 обогнала его по количеству выходящих за год игр. Насколько мне известно из личного опыта, у PS3 действительно выходило много замечательных эксклюзивных игр.<br>
# Wii с 2007 по 2011 годы занимала значительную роль среди популярных платформ, порой ее показатели как у PS3 и X360 вместе взятых по количеству вышедших игр.**

# %% [markdown]
# **Также мы можем сделать вывод, что время "жизни" поколения консолей в районе 6-8 лет, после чего их сменяет новое поколение. Также на диаграмме хорошо прослеживается, что количество выходящих игр для представленных на графике платформ постепенно уменьшается к 2016 году. Это обусловлено тем, что на рынке вышли консоли новых поколений, такие как PS4, Xbox One, Wii U.**

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# Еще можно попробовать получить примерный срок жизни платформ с помощью расчетов.</div>

# %% [markdown]
# ***
# **Для построения прогноза на 2017 год нам следует отобрать актуальные данные. В качестве таковых определим данные с 2014 по 2016 годы.**

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# Ты все отлично проанализировала и объяснила, но актуальный период выбрала  больше чем нужно. В этот срез попадут уже неактуальные платформы.
#
# Учитывая высокую динамичность рынка, мы можем сделать вывод, что для дальнейшего анализа нам потребуются данные по платформам, возникшим не ранее 3 лет назад по отношению к 2017 году, на который нам нужно сделать прогноз и запланировать рекламные кампании. Так мы сможем выделить успешные платформы, которые на 2017 год будут находиться в периоде финального роста или выйдут на плато. </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Окей, исправилась) Я просто подумала, что нам понадобится информация за прошлые периоды, чтобы прослеживался весь цикл становления платформ популярными, а затем их постепенный уход с рынка
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍 Весь цикл мы проследили, чтобы как раз определить срок жизни платформы и выбрать актуальный период </div>

# %% [markdown]
# **Визуализируем информацию о продажах игр с 2014 по 2016 годы, чтобы установить, какие платформы лидируют по продажам, растут или падают.**

# %%
# Фильтруем данные по годам
filtered_df3 = df[df['year_of_release'] >= 2014]

# Распределение платформ по годам с суммой продаж
platforms_sales_per_year = filtered_df3.groupby(['platform', 'year_of_release'])['total_sales'].sum().reset_index()

# Сортируем по общей сумме продаж
platforms_sales_per_year_sorted = platforms_sales_per_year.groupby('platform')['total_sales'].sum().sort_values(ascending=False).index

# Визуализируем данные с сортировкой и подписями годов
fig = px.bar(platforms_sales_per_year, x='total_sales', y='platform', color='year_of_release',
             title='Сумма продаж платформ по годам',
             labels={'platform': 'Платформа', 'total_sales': 'Сумма продаж', 'year_of_release': 'Год'},
             color_discrete_sequence=px.colors.qualitative.Set1,
             category_orders={'platform': platforms_sales_per_year_sorted},
             text='year_of_release')  # Добавляем подписи годов

fig.show()
# Out:
# <div>                            <div id="d183d823-f909-4145-ad3c-0fc07f274b6d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d183d823-f909-4145-ad3c-0fc07f274b6d")) {                    Plotly.newPlot(                        "d183d823-f909-4145-ad3c-0fc07f274b6d",                        [{"alignmentgroup":"True","hovertemplate":"\u0421\u0443\u043c\u043c\u0430 \u043f\u0440\u043e\u0434\u0430\u0436=%{x}<br>\u041f\u043b\u0430\u0442\u0444\u043e\u0440\u043c\u0430=%{y}<br>\u0413\u043e\u0434=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[2014,2015,2016,2014,2015,2016,2014,2015,2016,2014,2015,2016,2014,2015,2014,2015,2016,2014,2015,2016,2014,2015,2016,2014,2015,2016,2014,2015,2016],"coloraxis":"coloraxis","pattern":{"shape":""}},"name
# ...

# %% [markdown]
# **Итак, в наш Топ по продажам игр с 2014 по 2016 годы вошли платформы PS4, XOne, 3DS (но у нее продажи уже начали падать).<br>
# Мы видим, что продажи у консолей нового поколения - PS4 и XOne, вышедших на рынок в 2013 году, плавно начинают расти к 2016 году (в документантации было указано, что за 2016 год данные могут быть неполными). Эти платформы мы однозначно можем считать потенциально прибыльными в будущем 2017 году, и далее на протяжении нескольких лет они будут занимать лидирующие позиции на рынке игровых приставок.**

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
#
# PS4 и XOne действительно можно назвать потенциально прибыльными платформами, но точно ли это относится к WiiU?</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Поправила вывод
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# **Еще на графике заметна закономерность, что как только на рынке появляются консоли нового поколения, тут же начинают падать продажи на консоли этих же марок предыдущего поколения.**

# %% [markdown]
# **Построим график «ящик с усами» по глобальным продажам игр в разбивке по платформам:**

# %%
# Визуализируем "ящик с усами" по глобальным продажам игр в разбивке по платформам
fig = px.box(filtered_df3, x='platform', y='total_sales',
             title='Глобальные продажи игр по платформам (с 2014 года)',
             labels={'platform': 'Платформа', 'total_sales': 'Глобальные продажи', 'name': 'Название игры'},
             hover_data=['name'],  # Добавляем название игры в hover
             points="all")  # Отображаем все точки для лучшей детализации
# Удлиняем график
fig.update_layout(height=1200)
fig.show()
# Out:
# <div>                            <div id="cf163d73-179a-4fe7-8d37-dd28cc9eca85" class="plotly-graph-div" style="height:1200px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cf163d73-179a-4fe7-8d37-dd28cc9eca85")) {                    Plotly.newPlot(                        "cf163d73-179a-4fe7-8d37-dd28cc9eca85",                        [{"alignmentgroup":"True","boxpoints":"all","customdata":[["Call of Duty: Black Ops 3"],["Grand Theft Auto V"],["Pokemon Omega Ruby/Pokemon Alpha Sapphire"],["FIFA 16"],["Star Wars Battlefront (2015)"],["Call of Duty: Advanced Warfare"],["FIFA 17"],["Super Smash Bros. for Wii U and 3DS"],["Call of Duty: Black Ops 3"],["Fallout 4"],["Pokemon Sun/Moon"],["Mario Kart 8"],["FIFA 15"],["Destiny"],["Grand Theft Auto V"],["Uncharted 4: A Thief's End"],["Call of Duty: Ad
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# Тут лучше построить две визуализации. Одну не ограничивая продажи, чтобы рассмотреть выбросы, а на другой ограничить диапазон значений продаж ,чтобы отчетливо рассмотреть сами боксплоты. </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# После изменения актуального периода боксплоты стали видны и на одном графике))
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# **По полученным боксплотам можно сделать выводы, что в исследуемом периоде абсолютным рекордсменом по продажам некоторых игр стала платформа PS4. Игра Call of Duty: Black Ops 3 побила все рекорды, ее продажи составили 14,63 миллионов проданных копий! Также отличилась GTA V (12,62 млн).<br>
# У 3DS были отличные продажи по Pokemon Omega Ruby (11,68 млн).<br>
# На XOne лидерами по продажам также стали Call of Duty: Black Ops 3 и GTA V.**

# %%
#для сравнения с играми-лидерами посмотрим на медианные значения продаж игр по каждой из платформ
filtered_df3.groupby('platform')['total_sales'].median().sort_values(ascending=False).reset_index()
# Out:
#   platform  total_sales
# 0     XOne        0.205
# 1     WiiU        0.190
# 2      PS4        0.185
# 3      Wii        0.180
# 4     X360        0.180
# 5      PS3        0.110
# 6      3DS        0.090
# 7       PC        0.060
# 8      PSV        0.040
# 9      PSP        0.020

# %% [markdown]
# **Первое место по продажам среднестатистической игры заняла XOne - 0,21 млн проданных по миру копий. Второе место поделили между собой WiiU и PS4 (примерно по 0, 19 млн копий).**

# %% [markdown]
# ***
# **Посмотрим, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Построим диаграмму рассеяния. В качестве примеров разберем платформы PS4 и XOne, а также 3DS и PS3 (так как у них самые большие суммы продаж).**

# %%
#напишем функцию для построения диаграмм рассеяния по платформам и расчета корреляции
def scatter_plot_and_correlation(df, platform):
    # Фильтруем данные только для указанной платформы
    df_platform = df[df['platform'] == platform]

    # Визуализируем диаграмму рассеяния
    fig = px.scatter(df_platform, x='user_score', y='critic_score', size='total_sales', color='total_sales',
                     hover_data=['name'], labels={'user_score': 'Отзывы пользователей', 'critic_score': 'Отзывы критиков'},
                     title=f'Влияние отзывов на продажи (платформа {platform})')

    fig.show()

    # Посчитаем корреляцию
    correlation_matrix = df_platform[['user_score', 'critic_score', 'total_sales']].corr()

    # Выведем результат
    print(f'Корреляционная матрица для {platform}:\n{correlation_matrix}')

    return correlation_matrix

# %%
# Построим диаграмму рассеяния для PS4 и выведем матрицу корреляции
correlation_PS4 = scatter_plot_and_correlation(filtered_df3, 'PS4')
# Out:
# <div>                            <div id="33672a85-101b-4cbb-ab4d-2380cdbc4d9a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("33672a85-101b-4cbb-ab4d-2380cdbc4d9a")) {                    Plotly.newPlot(                        "33672a85-101b-4cbb-ab4d-2380cdbc4d9a",                        [{"customdata":[["Call of Duty: Black Ops 3"],["Grand Theft Auto V"],["FIFA 16"],["Star Wars Battlefront (2015)"],["Call of Duty: Advanced Warfare"],["FIFA 17"],["Fallout 4"],["FIFA 15"],["Destiny"],["Uncharted 4: A Thief's End"],["The Last of Us"],["Uncharted: The Nathan Drake Collection"],["Call of Duty: Infinite Warfare"],["Minecraft"],["Battlefield 1"],["Watch Dogs"],["Far Cry 4"],["The Witcher 3: Wild Hunt"],["Assassin's Creed: Unity"],["Batman: Arkham Knight
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# Зависимость продаж нагляднее все-таки рассматривать отдельно от оценок пользователей и отдельно от оценок критиков. </div>

# %% [markdown]
# **По полученной диаграмме рассеяния видно, что преимущественно у игр были хорошие продажи, если оценки пользователей и оценки критиков были высокими, но в то же время есть игры, у которых были хорошие продажи и высокие оценки критиков в то время как пользователи оценили их низко. Обратной же ситуации не наблюдается - то есть хороших продаж у игр с низкими оценками критиков и высоким признанием игроков.**

# %% [markdown]
# **Итак, выходит, что оценки критиков и игроков коррелируют между собой, обнаружена средняя положительная корреляция. На продажи оценки пользователей не влияют, а оценки критиков влияют в некоторой степени.**

# %% [markdown]
# **Теперь взглянем, какие результаты у нас получатся по платформе XOne.**

# %%
# Построим диаграмму рассеяния для XOne и выведем матрицу корреляции
correlation_XOne = scatter_plot_and_correlation(filtered_df3, 'XOne')
# Out:
# <div>                            <div id="bcadc950-e0a1-4593-88f9-3d52510cb99b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bcadc950-e0a1-4593-88f9-3d52510cb99b")) {                    Plotly.newPlot(                        "bcadc950-e0a1-4593-88f9-3d52510cb99b",                        [{"customdata":[["Call of Duty: Black Ops 3"],["Grand Theft Auto V"],["Call of Duty: Advanced Warfare"],["Halo 5: Guardians"],["Fallout 4"],["Star Wars Battlefront (2015)"],["Assassin's Creed: Unity"],["Destiny"],["Gears of War: Ultimate Edition"],["FIFA 16"],["Halo: The Master Chief Collection"],["Titanfall"],["Minecraft"],["FIFA 17"],["Call of Duty: Infinite Warfare"],["Madden NFL 16"],["NBA 2K16"],["Battlefield 1"],["FIFA 15"],["Tom Clancy's The Division"],["Fo
# ...

# %% [markdown]
# **Мы видим похожую ситуацию: есть игры с высокими продажами и отличными оценками критиков, при этом недооцененные игроками. А в целом чем выше оценки, тем больше продажи, что вполне логично.**

# %% [markdown]
# **Относительно корреляции тоже получились схожие с PS4 результаты: между оценками критиков и пользователей установлена средняя корреляция, а на продажи игр больше влияют оценки критиков нежели пользователей.**

# %%
# Построим диаграмму рассеяния для 3DS и выведем матрицу корреляции
correlation_3DS = scatter_plot_and_correlation(filtered_df3, '3DS')
# Out:
# <div>                            <div id="1eea2db1-9e19-46a3-9e5b-f39605b0a7ae" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1eea2db1-9e19-46a3-9e5b-f39605b0a7ae")) {                    Plotly.newPlot(                        "1eea2db1-9e19-46a3-9e5b-f39605b0a7ae",                        [{"customdata":[["Pokemon Omega Ruby/Pokemon Alpha Sapphire"],["Super Smash Bros. for Wii U and 3DS"],["Pokemon Sun/Moon"],["Monster Hunter 4 Ultimate"],["Monster Hunter X"],["Yokai Watch 2 Ganso/Honke"],["Animal Crossing: Happy Home Designer"],["Yokai Watch 2 Shinuchi"],["The Legend of Zelda: Majora's Mask 3D"],["Yokai Watch Busters"],["Kirby: Triple Deluxe"],[" Fire Emblem Fates"],["Yoshi's New Island"],["Yokai Watch 3"],["Pokemon Super Mystery Dungeon"],["The L
# ...

# %% [markdown]
# **Картина в целом сохраняется. Но по 3DS отзывы критиков и пользователей сильно коррелируют между собой.**

# %%
# Построим диаграмму рассеяния для PS3 и выведем матрицу корреляции
correlation_PS3 = scatter_plot_and_correlation(filtered_df3, 'PS3')
# Out:
# <div>                            <div id="3925833e-20bc-4101-ab7b-51fe4b56f591" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3925833e-20bc-4101-ab7b-51fe4b56f591")) {                    Plotly.newPlot(                        "3925833e-20bc-4101-ab7b-51fe4b56f591",                        [{"customdata":[["Minecraft"],["Call of Duty: Advanced Warfare"],["FIFA 15"],["FIFA 16"],["Watch Dogs"],["Call of Duty: Black Ops 3"],["Destiny"],["Madden NFL 15"],["NBA 2K15"],["Far Cry 4"],["Assassin's Creed: Rogue"],["Dark Souls II"],["Kingdom Hearts II"],["Disney Infinity 2.0: Marvel Super Heroes"],["The LEGO Movie Videogame"],["South Park: The Stick of Truth"],["LEGO Jurassic World"],["The Evil Within"],["WWE 2K15"],["Madden NFL 16"],["Lego Batman 3: Beyond G
# ...

# %% [markdown]
# **По диаграмме рассеяния видно, что ситуация в целом по платформам похожая, значит наши выводы можно признать корректными для всех игровых консолей. Что же касается корреляции, то мы видим что отзывы критиков и игроков можно считать в определенной степени взаимосвязанными, а вот на сумму продаж отзывы пользователей как правило вообще не влияют, а отзывы критиков влияют отчасти.**

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# Чтобы сделать итоговый вывод о зависимости продаж от оценок, нам нужно рассмотреть еще хотя бы 2 платформы подобным образом (как PS3 и X360). Так как код будет повторяться, его можно выполнять в цикле или написать небольшую функцию.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Я переделала на более актуальные PS4 и XOne, а ниже идет анализ по всем исследуемым платформам за 2014-2016 годы вместе.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера 2:</b>
#
# Но анализ по всем платформам непоказателен, к тому же там тоже участвуют PS4 и XOne. Необходимо рассмотреть несколько платформ отдельно друг от друга.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Рассмотрела еще две платформы) Написала функцию
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 3:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# **Посмотрим на общее распределение игр по жанрам:**

# %%
# Группируем и сортируем данные
genre_counts = filtered_df3.groupby('genre')['name'].count().sort_values(ascending=False)

# Визуализируем данные
plt.figure(figsize=(12, 6))
ax = sns.countplot(y='genre', data=filtered_df3, order=genre_counts.index, palette='viridis')

# Добавляем аннотации с количеством игр к каждому столбцу
for p in ax.patches:
    ax.annotate(f'{p.get_width()}',
                (p.get_width(), p.get_y() + p.get_height() / 2),
                ha='left', va='center', color='black', fontsize=10)

plt.title('Количество игр в каждом жанре')
plt.xlabel('Количество игр')
plt.ylabel('Жанр')
plt.show()

# %% [markdown]
# **С 2014 по 2017 годы больше всего выходило игр в жанре Action (619 шт). Также популярны игры жанра Role-Playing (221) и Adventure (185). Меньше же всего выходило игр в жанре Puzzle (14) и Strategy (37).**

# %% [markdown]
# **Теперь изучим, игры каких жанров продавались лучше всего:**

# %%
# Группируем и сортируем данные
genre_sales = filtered_df3.groupby('genre')['total_sales'].sum().sort_values(ascending=False)

# Визуализируем данные
plt.figure(figsize=(12, 6))
ax = sns.barplot(x=genre_sales.values, y=genre_sales.index, palette='viridis')

# Добавляем подписи к каждому столбцу
for p in ax.patches:
    ax.annotate(f'{p.get_width():,.2f} млн.',
                (p.get_width(), p.get_y() + p.get_height() / 2),
                ha='left', va='center', color='black', fontsize=10)

plt.title('Сумма общих продаж по жанрам')
plt.xlabel('Сумма общих продаж (в миллионах копий)')
plt.ylabel('Жанр')
plt.show()

# %% [markdown]
# **По полученной столбчатой диаграмме мы видим, что жанр Action опять же в лидерах и по числу проданных копий (199 млн), второе место занимают игры Shooter (170 млн), третье - Sports с 109,5 млн. Замыкают же список хорошо продаваемых жанров Puzzle (2 млн) и Strategy (4 млн).**

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# Определять прибыльность жанров только по суммарным продажам или только по количеству релизов не совсем корректно, нужно учитывать их соотношение. А лучше сразу рассматривать медианные значения продаж, они являются наиболее объективным показателем прибыльности, так как менее подвержены влиянию выбросов (а в игровой индустрии их достаточно много за счет продаж очень популярных и хитовых игр)</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Спасибо за очень важную поправку! Учла ее ниже!)
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# **Теперь определим прибыльность игровых жанров, рассчитав медианные значения проданных копий по каждому жанру (для исключения влияния выбросов):**

# %%
# Группируем и сортируем данные
genre_median_sales = filtered_df3.groupby('genre')['total_sales'].median().sort_values(ascending=False)

# Визуализируем данные
plt.figure(figsize=(12, 6))
ax = sns.barplot(x=genre_median_sales.values, y=genre_median_sales.index, palette='viridis')

# Добавляем подписи к каждому столбцу
for p in ax.patches:
    ax.annotate(f'{p.get_width():,.2f} млн.',
                (p.get_width(), p.get_y() + p.get_height() / 2),
                ha='left', va='center', color='black', fontsize=10)

plt.title('Медианные продажи по жанрам')
plt.xlabel('Медианные продажи (в миллионах копий)')
plt.ylabel('Жанр')
plt.show()

# %% [markdown]
# **Выходит, что самыми продаваемыми жанрами как правило являлись игры Shooter (0,52 млн копий), за ними с приличным отрывом идут Sports (0,18 млн) и Platform (0,14 млн). Полученные результаты команде "Стримчика" нужно будет непременно учесть в качестве потенциально определяющих успешность игры закономерностей.**

# %% [markdown]
# ## Составим портрет пользователя каждого региона

# %% [markdown]
# **Постараемся разобраться, что из себя представляет среднестатистический пользователь Северной Америки, Европы и Японии.**

# %% [markdown]
# **Сначала узнаем, какие платформы наиболее популярны в разных регионах:**

# %%
# Функция для форматирования значений в проценты
def percentformat(x):
    return f"{x:.2%}"

# Группируем и сортируем данные
total_sales_na = filtered_df3['na_sales'].sum()
total_sales_eu = filtered_df3['eu_sales'].sum()
total_sales_jp = filtered_df3['jp_sales'].sum()

top_platforms_na = filtered_df3.groupby('platform')['na_sales'].sum().sort_values(ascending=False).head(5)
top_platforms_eu = filtered_df3.groupby('platform')['eu_sales'].sum().sort_values(ascending=False).head(5)
top_platforms_jp = filtered_df3.groupby('platform')['jp_sales'].sum().sort_values(ascending=False).head(5)

# Создаем график для Северной Америки
fig_na = px.bar(x=top_platforms_na.index, y=top_platforms_na / total_sales_na, text=top_platforms_na.round(2),
                labels={'x': 'Платформа', 'y': 'Доля продаж'},
                title='Продажи в Северной Америке (доля от общих продаж)')
fig_na.update_traces(marker_color='rgba(0, 128, 255, 0.7)', textposition='auto')
fig_na.update_yaxes(tickformat=".2%")

# Создаем график для Европы
fig_eu = px.bar(x=top_platforms_eu.index, y=top_platforms_eu / total_sales_eu, text=top_platforms_eu.round(2),
                labels={'x': 'Платформа', 'y': 'Доля продаж'},
                title='Продажи в Европе (доля от общих продаж)')
fig_eu.update_traces(marker_color='rgba(255, 0, 0, 0.7)', textposition='auto')
fig_eu.update_yaxes(tickformat=".2%")

# Создаем график для Японии
fig_jp = px.bar(x=top_platforms_jp.index, y=top_platforms_jp / total_sales_jp, text=top_platforms_jp.round(2),
                labels={'x': 'Платформа', 'y': 'Доля продаж'},
                title='Продажи в Японии (доля от общих продаж)')
fig_jp.update_traces(marker_color='rgba(0, 255, 0, 0.7)', textposition='auto')
fig_jp.update_yaxes(tickformat=".2%")

# Наложим графики друг на друга
fig_na.update_layout(height=300, showlegend=False)
fig_eu.update_layout(height=300, showlegend=False)
fig_jp.update_layout(height=300, showlegend=False)

fig_na.show()
fig_eu.show()
fig_jp.show()
# Out:
# <div>                            <div id="8f72f55d-36f5-4fa8-a605-a5da92f696db" class="plotly-graph-div" style="height:300px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8f72f55d-36f5-4fa8-a605-a5da92f696db")) {                    Plotly.newPlot(                        "8f72f55d-36f5-4fa8-a605-a5da92f696db",                        [{"alignmentgroup":"True","hovertemplate":"\u041f\u043b\u0430\u0442\u0444\u043e\u0440\u043c\u0430=%{x}<br>\u0414\u043e\u043b\u044f \u043f\u0440\u043e\u0434\u0430\u0436=%{y}<br>text=%{text}<extra></extra>","legendgroup":"","marker":{"color":"rgba(0, 128, 255, 0.7)","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[98.61,81.27,28.3,22.64,22.05],"textposition":"auto","x":["PS4","XOne","X360","3DS","PS3"],"xaxis":"x","y":[
# ...

# %% [markdown]
# **Выходит, что в Северной Америке и Европе пользователи отдают предпочтение PS4 (почти 35% и 48% пользователей соответственно), а в Японии - 3DS (47,5%). Также в Северной Америке популярен и XOne (28,6%), в то время как в Европе его выбирают лишь 17% игроков.**

# %% [markdown]
# **Теперь изучим, какие жанры игр предпочитают пользователи в различных регионах:**

# %%
# Группируем и сортируем данные по жанрам
total_sales_na = filtered_df3['na_sales'].sum()
total_sales_eu = filtered_df3['eu_sales'].sum()
total_sales_jp = filtered_df3['jp_sales'].sum()

top_genres_na = filtered_df3.groupby('genre')['na_sales'].sum().sort_values(ascending=False).head(5)
top_genres_eu = filtered_df3.groupby('genre')['eu_sales'].sum().sort_values(ascending=False).head(5)
top_genres_jp = filtered_df3.groupby('genre')['jp_sales'].sum().sort_values(ascending=False).head(5)

# Создаем график для Северной Америки
fig_na_genre = px.bar(x=top_genres_na.index, y=top_genres_na / total_sales_na, text=top_genres_na.round(2),
                      labels={'x': 'Жанр', 'y': 'Доля продаж'},
                      title='Продажи в Северной Америке по жанрам (доля от общих продаж)')
fig_na_genre.update_traces(marker_color='rgba(0, 128, 255, 0.7)', textposition='auto')
fig_na_genre.update_yaxes(tickformat=".2%")

# Создаем график для Европы
fig_eu_genre = px.bar(x=top_genres_eu.index, y=top_genres_eu / total_sales_eu, text=top_genres_eu.round(2),
                      labels={'x': 'Жанр', 'y': 'Доля продаж'},
                      title='Продажи в Европе по жанрам (доля от общих продаж)')
fig_eu_genre.update_traces(marker_color='rgba(255, 0, 0, 0.7)', textposition='auto')
fig_eu_genre.update_yaxes(tickformat=".2%")

# Создаем график для Японии
fig_jp_genre = px.bar(x=top_genres_jp.index, y=top_genres_jp / total_sales_jp, text=top_genres_jp.round(2),
                      labels={'x': 'Жанр', 'y': 'Доля продаж'},
                      title='Продажи в Японии по жанрам (доля от общих продаж)')
fig_jp_genre.update_traces(marker_color='rgba(0, 255, 0, 0.7)', textposition='auto')
fig_jp_genre.update_yaxes(tickformat=".2%")

# Наложим графики друг на друга
fig_na_genre.update_layout(height=300, showlegend=False)
fig_eu_genre.update_layout(height=300, showlegend=False)
fig_jp_genre.update_layout(height=300, showlegend=False)

fig_na_genre.show()
fig_eu_genre.show()
fig_jp_genre.show()
# Out:
# <div>                            <div id="7d932a3d-7c6e-461b-849f-4015d3f64935" class="plotly-graph-div" style="height:300px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7d932a3d-7c6e-461b-849f-4015d3f64935")) {                    Plotly.newPlot(                        "7d932a3d-7c6e-461b-849f-4015d3f64935",                        [{"alignmentgroup":"True","hovertemplate":"\u0416\u0430\u043d\u0440=%{x}<br>\u0414\u043e\u043b\u044f \u043f\u0440\u043e\u0434\u0430\u0436=%{y}<br>text=%{text}<extra></extra>","legendgroup":"","marker":{"color":"rgba(0, 128, 255, 0.7)","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[79.02,72.53,46.13,33.47,15.05],"textposition":"auto","x":["Shooter","Action","Sports","Role-Playing","Misc"],"xaxis":"x","y":[0.278180666
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# Заметила ли ты, что код для построения диаграмм повторяется? Его можно обернуть в функцию.  </div>

# %% [markdown]
# **По полученным столбчатым диаграммам можно сделать вывод, что в Северной Америке и в Европе ситуация схожая: игроки чаще всего покупают игры жанра Action (в районе 26%) и Shooter (примерно 26%). Что же касается Японии - там пользователи отдают предпочтение играм жанров Role-Playing (33,5%) и Action (32%).**

# %% [markdown]
# **Любовь японцев к ролевым играм (RPG) может быть объяснена несколькими факторами:<br>
# 1). Культурные особенности: Япония имеет богатую культурную и историческую традицию, и ролевые игры часто включают элементы японской мифологии, фольклора и истории. Игры часто предлагают уникальные сюжеты и персонажей, которые могут быть особенно привлекательными для японской аудитории.<br>
# 2). Нарратив и персонажи: Ролевые игры обычно акцентируют внимание на нарративе и развитии персонажей. Японцы могут приветствовать глубокие сюжеты, эмоциональные персонажи и взаимодействие между ними.<br>
# 3). Геймдизайн: Японские RPG часто отличаются уникальным геймдизайном, включая характерные боевые системы, магию и другие элементы. Эти особенности могут придавать играм узнаваемый стиль.<br>
# 4). Популярные франшизы: Некоторые из самых известных игровых франшиз, такие как Final Fantasy, Dragon Quest, и Persona, являются японскими RPG. Они завоевали популярность как в Японии, так и за её пределами.<br>
# 5). Социальный аспект: Многие RPG предоставляют возможность игрокам взаимодействовать с другими игроками внутри игрового мира. В Японии социальные аспекты могут быть особенно привлекательными.**

# %% [markdown]
# **Почему в Европе и Северной Америке популярны игры в жанре Action и Shooter:<br>
# 1). Культурные тенденции: В Северной Америке и Европе исторически сложились тенденции к предпочтению более динамичных и быстрых форм развлечений. Жанры Action и Shooter обычно предлагают более интенсивный и динамичный геймплей, что может соответствовать культурным ожиданиям.<br>
# 2). Развитие индустрии: В Северной Америке и Европе широко развита индустрия видеоигр, и эти регионы являются домом для многих известных студий разработки игр. Жанры Action и Shooter часто привлекают больше внимания и инвестиций со стороны крупных издателей.<br>
# 3). История игровой индустрии: Многие успешные и популярные игры в жанре Action и Shooter были разработаны в Северной Америке и Европе. Это включает в себя такие франшизы, как Grand Theft Auto, Call of Duty, Assassin's Creed, Counter-Strike, Rainbow Six Siege. Успех этих игр может повлиять на предпочтения игроков.<br>
# 4). Специфика рынка: Рынок видеоигр в Северной Америке и Европе характеризуется высокой конкуренцией и разнообразием предложений. Жанры Action и Shooter могут успешно привлекать внимание игроков своим разнообразием поджанров и стилей.<br>
# 5). Социокультурные аспекты: Общество в Северной Америке и Европе может проявлять интерес к более реалистичным, спектакульным и эмоциональным видеоиграм. Жанры Action и Shooter часто отвечают этим ожиданиям, предлагая захватывающие сценарии и бурные действия.**

# %% [markdown]
# **Посмотрим, влияет ли возрастной рейтинг на продажи видеоигр по регионам:**

# %%
# Группируем и сортируем данные по рейтингам
total_sales_na = filtered_df3['na_sales'].sum()
total_sales_eu = filtered_df3['eu_sales'].sum()
total_sales_jp = filtered_df3['jp_sales'].sum()

top_ratings_na = filtered_df3.groupby('rating')['na_sales'].sum().sort_values(ascending=False)
top_ratings_eu = filtered_df3.groupby('rating')['eu_sales'].sum().sort_values(ascending=False)
top_ratings_jp = filtered_df3.groupby('rating')['jp_sales'].sum().sort_values(ascending=False)

# Создаем график для Северной Америки
fig_na_rating = px.bar(x=top_ratings_na.index, y=top_ratings_na / total_sales_na, text=top_ratings_na.round(2),
                      labels={'x': 'Рейтинг', 'y': 'Доля продаж'},
                      title='Продажи в Северной Америке по рейтингу (доля от общих продаж)')
fig_na_rating.update_traces(marker_color='rgba(0, 128, 255, 0.7)', textposition='auto')
fig_na_rating.update_yaxes(tickformat=".2%")

# Создаем график для Европы
fig_eu_rating = px.bar(x=top_ratings_eu.index, y=top_ratings_eu / total_sales_eu, text=top_ratings_eu.round(2),
                      labels={'x': 'Рейтинг', 'y': 'Доля продаж'},
                      title='Продажи в Европе по рейтингу (доля от общих продаж)')
fig_eu_rating.update_traces(marker_color='rgba(255, 0, 0, 0.7)', textposition='auto')
fig_eu_rating.update_yaxes(tickformat=".2%")

# Создаем график для Японии
fig_jp_rating = px.bar(x=top_ratings_jp.index, y=top_ratings_jp / total_sales_jp, text=top_ratings_jp.round(2),
                      labels={'x': 'Рейтинг', 'y': 'Доля продаж'},
                      title='Продажи в Японии по рейтингу (доля от общих продаж)')
fig_jp_rating.update_traces(marker_color='rgba(0, 255, 0, 0.7)', textposition='auto')
fig_jp_rating.update_yaxes(tickformat=".2%")

# Наложим графики друг на друга
fig_na_rating.update_layout(height=300, showlegend=False)
fig_eu_rating.update_layout(height=300, showlegend=False)
fig_jp_rating.update_layout(height=300, showlegend=False)

fig_na_rating.show()
fig_eu_rating.show()
fig_jp_rating.show()
# Out:
# <div>                            <div id="2e90212d-3b5f-41e3-bc34-8ee1aa118b5e" class="plotly-graph-div" style="height:300px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2e90212d-3b5f-41e3-bc34-8ee1aa118b5e")) {                    Plotly.newPlot(                        "2e90212d-3b5f-41e3-bc34-8ee1aa118b5e",                        [{"alignmentgroup":"True","hovertemplate":"\u0420\u0435\u0439\u0442\u0438\u043d\u0433=%{x}<br>\u0414\u043e\u043b\u044f \u043f\u0440\u043e\u0434\u0430\u0436=%{y}<br>text=%{text}<extra></extra>","legendgroup":"","marker":{"color":"rgba(0, 128, 255, 0.7)","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[96.42,50.74,38.95,33.23],"textposition":"auto","x":["M","E","T","E10+"],"xaxis":"x","y":[0.3394353305639657,0.178624234
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# А если заполнить пропуски в рейтингах каким-нибудь единым значением, означающим отсутствие рейтинга, то можно будет увидеть интересную особенность)</div>

# %% [markdown]
# **Картина в Северной Америке и Европе вновь оказалась идентичная: наиболее популярны игры с возрастными рейтингами "M" (Mature) (по 34%) и "E" (Everyone) (в районе 20%). Относительно Японии можно сказать, что 16% пользователей выбирают игры с рейтингом "T" (Teen), а около 10% с рейтингом "E" (Everyone).**

# %% [markdown]
# ## Проверка гипотез

# %% [markdown]
# **Сформулируем гипотезы и проведем t-тест с использованием scipy.stats:<br>
# H0 (нулевая гипотеза): Средние рейтинги платформ XOne и PC одинаковы.<br>
# H1 (альтернативная гипотеза): Средние рейтинги платформ XOne и PC различаются.**

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Здорово, что формулируешь гипотезы вначале шага </div>

# %% [markdown]
# **Мы используем уровень значимости 0,05. Если P-значение, полученное в результате теста, окажется меньше 0,05, то мы отвергнем нулевую гипотезу в пользу альтернативной.**

# %%
# Разделяем данные по платформам XOne и PC
ratings_xone = filtered_df3[filtered_df3['platform'] == 'XOne']['user_score'].dropna()
ratings_pc = filtered_df3[filtered_df3['platform'] == 'PC']['user_score'].dropna()

# Рассчитываем дисперсию и стандартное отклонение для пользовательских рейтингов на платформе XOne
variance_xone = ratings_xone.var()
std_dev_xone = ratings_xone.std()

# Рассчитываем дисперсию и стандартное отклонение для пользовательских рейтингов на платформе PC
variance_pc = ratings_pc.var()
std_dev_pc = ratings_pc.std()

# Выводим результаты
print(f'Дисперсия для пользовательских рейтингов на платформе XOne: {variance_xone:.4f}, Стандартное отклонение: {std_dev_xone:.4f}')
print(f'Дисперсия для пользовательских рейтингов на платформе PC: {variance_pc:.4f}, Стандартное отклонение: {std_dev_pc:.4f}')
# Out:
# Дисперсия для пользовательских рейтингов на платформе XOne: 1.8910, Стандартное отклонение: 1.3751
# Дисперсия для пользовательских рейтингов на платформе PC: 2.9012, Стандартное отклонение: 1.7033

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b>
#
# Кстати, можно не удалять пропуски из сравниваемых выборок, а передать в ttest_ind аргумент nan_policy с нужным значением, тогда они будут игнорироваться. Подробнее можно почитать [здесь](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.ttest_ind.html) </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# На этом месте код падает с ошибкой. Поэтому, к сожалению, дальнейшая проверка невозможна.
#
# Большая просьба отправлять на проверку проект с работающим кодом. Перед отправкой следует перезапустить весь проект `Kernel-->Restart & Run All` и убедиться, что все ячейки корректно отработали.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# **Так как дисперсия и стандартное отклонение близки друг к другу, при проведении t-теста не будем устанавливать параметр equal_var=False.**

# %%
# Проводим t-тест
t_statistic, p_value = st.ttest_ind(ratings_xone, ratings_pc)

# Уровень значимости
alpha = 0.05

# Выводим результаты
print(f'T-статистика: {t_statistic:.4f}')
print(f'P-значение: {p_value:.4f}')

# Проверяем гипотезу
if p_value < alpha:
    print("Отвергаем нулевую гипотезу: Средние рейтинги платформ XOne и PC различаются.")
else:
    print("Не удалось отвергнуть нулевую гипотезу: Нет оснований считать средние рейтинги различными.")
# Out:
# T-статистика: 1.6286
# P-значение: 0.1045
# Не удалось отвергнуть нулевую гипотезу: Нет оснований считать средние рейтинги различными.

# %% [markdown]
# **Исходя из результатов t-теста, у нас есть статистически значимые доказательства в пользу отсутствия различия средних пользовательских рейтингов между платформами XOne и PC. Таким образом, мы не отвергаем нулевую гипотезу о равенстве средних.**

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера 2:</b>
#
# В выводе утверждения противоречат друг другу (обрати внимание на последнее предложение).</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Исправилась))
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 3:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# **Сформулируем гипотезы:<br>
# Нулевая гипотеза (H0): Средние пользовательские рейтинги жанров Action и Sports одинаковы.<br>
# Альтернативная гипотеза (H1): Средние пользовательские рейтинги жанров Action и Sports различаются.**

# %%
# Разделяем данные по жанрам Action и Sports
ratings_action = filtered_df3[filtered_df3['genre'] == 'Action']['user_score'].dropna()
ratings_sports = filtered_df3[filtered_df3['genre'] == 'Sports']['user_score'].dropna()

# Рассчитываем дисперсию и стандартное отклонение для жанра Action
variance_action = filtered_df3[filtered_df3['genre'] == 'Action']['user_score'].var()
std_deviation_action = filtered_df3[filtered_df3['genre'] == 'Action']['user_score'].std()

# Рассчитываем дисперсию и стандартное отклонение для жанра Sports
variance_sports = filtered_df3[filtered_df3['genre'] == 'Sports']['user_score'].var()
std_deviation_sports = filtered_df3[filtered_df3['genre'] == 'Sports']['user_score'].std()

print(f'Дисперсия для жанра Action: {variance_action:.4f}, Стандартное отклонение: {std_deviation_action:.4f}')
print(f'Дисперсия для жанра Sports: {variance_sports:.4f}, Стандартное отклонение: {std_deviation_sports:.4f}')
# Out:
# Дисперсия для жанра Action: 1.8985, Стандартное отклонение: 1.3779
# Дисперсия для жанра Sports: 3.4470, Стандартное отклонение: 1.8566

# %% [markdown]
# **Так как дисперсия и стандартное отклонение близки друг к другу, при проведении t-теста не будем устанавливать параметр equal_var=False.**

# %%
# Проводим t-тест
t_statistic, p_value = st.ttest_ind(ratings_action, ratings_sports)

# Уровень значимости
alpha = 0.05

# Выводим результаты
print(f'T-статистика: {t_statistic:.4f}')
print(f'P-значение: {p_value}')

# Проверяем гипотезу
if p_value < alpha:
    print("Отвергаем нулевую гипотезу: Средние пользовательские рейтинги жанров Action и Sports различаются.")
else:
    print("Не удалось отвергнуть нулевую гипотезу: Нет оснований считать средние рейтинги различными.")
# Out:
# T-статистика: 9.4252
# P-значение: 2.8711147985105864e-19
# Отвергаем нулевую гипотезу: Средние пользовательские рейтинги жанров Action и Sports различаются.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера 2:</b>
#
# P-значение не нужно округлять, оно не должно быть равно 0</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Поправила
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 3:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# **На основе результатов теста можно сделать вывод о том, что у нас есть статистически значимые доказательства различия средних пользовательских рейтингов для жанров Action и Sports. Таким образом, мы отвергаем нулевую гипотезу о их одинаковости в пользу альтернативной гипотезы.**

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера 2:</b>
#
# Значение T-статистики нам не может говорить, что средний пользовательский рейтинг для жанра Action выше, так как мы проверяли двухстороннюю гипотезу.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Убрала это из вывода
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 3:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# **Нами было проведено исследование о популярных видеоиграх, продаваемых в различных регионах (Северная Америка, Европа, Япония и др.), предпочитаемых пользователями платформах, о рейтингах критиков и игроков с целью выявления потенциально интересных потребителям игр и планирования будущих рекламных кампаний интернет-магазина "Стримчик".<br>
# Сначала мы провели предобработку данных: привели названия столбцов к нижнему регистру, изменили типы столбцов, проверили данные на наличие пропусков, аномалий и дубликатов и удалили их, добавили дополнительный столбец, необходимый нам для анализа. Затем мы провели исследовательский анализ данных и установили:<br>
# -- До 1994 года выпускалось мало игр - эта индустрия еще только развивалась. Потом количество выпускаемых ежегодно игр стало резко расти. Пик мы наблюдаем в 2008 и 2009 годах (1427 и 1426 игр за год). Затем наблюдается спад в количестве выпускаемых ежегодно игр. Думаю это может быть обусловлено тем, что потребители стали более требовательными и искушенными, и разработка более современных игр требует больше времени на разработку, выявление и устранение багов, проработку сюжета, геймплея и т.п.<br>
# -- Самыми популярными платформами за исследуемый период являлись PS2, X360, PS3, Wii, DS и PS. Интересное наблюдение - персональные компьютеры не вошли в топ, хотя, безусловно, они и имеют большее распространение.<br>
# -- С 1994 по 2001 много игр выходило на платформу PS, а с 2000 по 2008 - на платформу PS2.
# С 2005 по 2011 DS занимала превосходные лидирующие позиции.
# Популярность PS3 и X360 с 2006 по 2016 годы можно сказать являлась тождественной и абсолютно сопоставимой (как известно, это действительно конкурирующие игровые приставки-аналоги от Sony и Microsoft, относящиеся к одному поколению). Как мы видим, сначала немного выигрывал X360, а потом PS3 обогнала его по количеству выходящих за год игр. Насколько мне известно из личного опыта, у PS3 действительно выходило много замечательных эксклюзивных игр.
# Wii с 2007 по 2011 годы занимала значительную роль среди популярных платформ, порой ее показатели как у PS3 и X360 вместе взятых по количеству вышедших игр.<br>
# -- Также мы смогли сделать вывод, что время "жизни" поколения консолей в районе 6-8 лет, после чего их сменяет новое поколение.<br>
# -- Для построения прогноза на 2017 год мы определили данные с 2004 по 2016 годы.<br>
# -- В Топ по продажам игр с 2014 по 2016 годы вошли платформы PS4, XOne, 3DS (но у нее продажи уже начали падать).
# Мы увидели, что продажи у консолей нового поколения - PS4 и XOne, вышедших на рынок в 2013 году, плавно начинают расти к 2016 году (в документантации было указано, что за 2016 год данные могут быть неполными). Эти платформы мы однозначно можем считать потенциально прибыльными в будущем 2017 году, и далее на протяжении нескольких лет они будут занимать лидирующие позиции на рынке игровых приставок.<br>
# -- Как только на рынке появляются консоли нового поколения, тут же начинают падать продажи на консоли этих же марок предыдущего поколения.<br>
# -- В исследуемом периоде абсолютным рекордсменом по продажам некоторых игр стала платформа PS4. Игра Call of Duty: Black Ops 3 побила все рекорды, ее продажи составили 14,63 миллионов проданных копий! Также отличилась GTA V (12,62 млн). У 3DS были отличные продажи по Pokemon Omega Ruby (11,68 млн). На XOne лидерами по продажам также стали Call of Duty: Black Ops 3 и GTA V.<br>
# -- Первое место по продажам среднестатистической игры заняла XOne - 0,21 млн проданных по миру копий. Второе место поделили между собой WiiU и PS4 (примерно по 0, 19 млн копий).<br>
# -- Преимущественно у игр были хорошие продажи, если оценки пользователей и оценки критиков были высокими, но в то же время есть игры, у которых были хорошие продажи и высокие оценки критиков в то время как пользователи оценили их низко. Обратной же ситуации не наблюдается - то есть хороших продаж у игр с низкими оценками критиков и высоким признанием игроков. Что же касается корреляции, то мы видим что отзывы критиков и игроков можно считать в определенной степени взаимосвязанными, а вот на сумму продаж отзывы пользователей как правило вообще не влияют, а отзывы критиков влияют отчасти.<br>
# -- С 2014 по 2017 годы больше всего выходило игр в жанре Action (619 шт). Также популярны игры жанра Role-Playing (221) и Adventure (185). Меньше же всего выходило игр в жанре Puzzle (14) и Strategy (37).<br>
# -- Жанр Action опять же в лидерах и по числу проданных копий (199 млн), второе место занимают игры Shooter (170 млн), третье - Sports с 109,5 млн. Замыкают же список хорошо продаваемых жанров Puzzle (2 млн) и Strategy (4 млн).<br>
# -- Самыми продаваемыми жанрами (при расчете с использованием медианы) как правило являлись игры Shooter (0,52 млн копий), за ними с приличным отрывом идут Sports (0,18 млн) и Platform (0,14 млн). Полученные результаты команде "Стримчика" нужно будет непременно учесть в качестве потенциально определяющих успешность игры закономерностей.**<br>
# ***
# **Затем мы перешли к составлению  портрета пользователя каждого региона и установили следующее:<br>
# 1). В Северной Америке и Европе пользователи отдают предпочтение PS4 (почти 35% и 48% пользователей соответственно), а в Японии - 3DS (47,5%). Также в Северной Америке популярен и XOne (28,6%), в то время как в Европе его выбирают лишь 17% игроков.<br>
# 2). По жанровым предпочтениям в Северной Америке и в Европе ситуация схожая: игроки чаще всего покупают игры жанра Action (в районе 26%) и Shooter (примерно 26%). Что же касается Японии - там пользователи отдают предпочтение играм жанров Role-Playing (33,5%) и Action (32%).<br>
# 3). По возрастным рейтингам картина в Северной Америке и Европе вновь оказалась идентичная: наиболее популярны игры с возрастными рейтингами "M" (Mature) (по 34%) и "E" (Everyone) (в районе 20%). Относительно Японии можно сказать, что 16% пользователей выбирают игры с рейтингом "T" (Teen), а около 10% с рейтингом "E" (Everyone).<br>**
# ***
# **В конце исследования мы сформулировали и проверили гипотезы.<br>
# 1). Исходя из результатов t-теста, у нас есть статистически значимые доказательства в пользу отсутствия различия средних пользовательских рейтингов между платформами XOne и PC. Таким образом, мы не отвергаем нулевую гипотезу о равенстве средних. <br>
# 2). На основе результатов теста можно сделать вывод о том, что у нас есть статистически значимые доказательства различия средних пользовательских рейтингов для жанров Action и Sports. Таким образом, мы отвергаем нулевую гипотезу о их одинаковости в пользу альтернативной гипотезы.**
# ***
# **В качестве рекомендаций отделу маркетинга можно выделить следующие:<br>
# 1). В 2017 году следует закупать у поставщиков для перепродажи игры на такие платформы как PS4 и XOne, а в Японии выгодно еще сделать упор на 3DS.<br>
# 2). Лучше всего будут покупать игры жанров Action, Shooter и Role-Playing.<br>
# 3). Следует выбирать для продажи игры известных зарекомендовавших себя серий, такие как Grand Theft Auto, Call of Duty, Assassin's Creed, Counter-Strike, Far Cry и др. У них уже сформирована своя аудитория и есть своя положительная репутация, пользователи всегда с нетерпением ожидают выхода новых релизов от известных игровых серий.<br>
# 4). Что касается рейтинга - в Северной Америке и Европе больше будут пользоваться популярностью игры с возрастными рейтингами "M" (Mature) и "E" (Everyone), а в Японии "T" (Teen) и "E" (Everyone).<br>
# 5). Также при выборе игр для интернет-магазина было бы преимуществом предварительно отслеживать, что у игр высокие рейтинги критиков - из прошлого опыта мы знаем, что это как правило достаточно ощутимо влиет на продажи.**

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера 2:</b>
#
# Хороший резюмирующий вывод. Еще можно добавить рекомендации отделу маркетинга для проведения рекламной кампании в 2017 году.
#
#
#
# **Хочу обратить твое внимание на то, что после исправления замечаний в некоторых пунктах исследования могут измениться результаты, поэтому нужно будет подкорректировать выводы.**</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Добавила рекомендации отделу маркетинга
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 3:</b> Отлично, исправлено!👍  </div>
